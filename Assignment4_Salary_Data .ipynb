# %%
import pandas as pd
import numpy as np

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv('Salary_Data (1).csv')
data.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
import seaborn as sns

# %%
# Create a distribution plot for the 'YearsExperience'
sns.distplot(data['YearsExperience'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
# Create a distribution plot for the 'Salary'
sns.distplot(data['Salary'])
# Out:
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
# Calculate the correlation matrix for the dataset
data.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %%
# This code creates a regression plot using Seaborn library
sns.regplot(x=data['YearsExperience'],y=data['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# # Model Building

# %%
import statsmodels.formula.api as smf

# %%
# Fit an Ordinary Least Squares (OLS) model using statsmodels formula API
model=smf.ols("Salary~YearsExperience",data=data).fit()

# %%
model.params   # Retrieve the parameters of a statistical model
# Out:
# Intercept          25792.200199
# YearsExperience     9449.962321
# dtype: float64

# %%
model.tvalues    # Display the t-values of a statistical model
# Out:
# Intercept          11.346940
# YearsExperience    24.950094
# dtype: float64

# %%
 model.pvalues     # Display the p-values of a statistical model
# Out:
# Intercept          5.511950e-12
# YearsExperience    1.143068e-20
# dtype: float64

# %%
model.rsquared     # Retrieve the R-squared from the 'model'
# Out:
# 0.9569566641435086

# %%
model.rsquared_adj    # Access the adjusted R-squared value from the statistical model
# Out:
# 0.9554194021486339

# %% [markdown]
# # Model Predictions

# %%
Salary = (25792.200199) + (9449.962321)*(3)
Salary
# Out:
# 54142.087162

# %%
new_data=pd.Series([3,5])
new_data
# Out:
# 0    3
# 1    5
# dtype: int64

# %%
# Create a new DataFrame 'data_pred' with the 'new_data' as a column labeled 'YearsExperience'
data_pred=pd.DataFrame(new_data,columns=['YearsExperience'])
data_pred
# Out:
#    YearsExperience
# 0                3
# 1                5

# %%
# Predict using the 'predict' method 
model.predict(data_pred)
# Out:
# 0    54142.087163
# 1    73042.011806
# dtype: float64
